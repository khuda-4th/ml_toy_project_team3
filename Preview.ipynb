# %%
import pandas as pd
import numpy as np

# %%
from matplotlib import rc

# %%
data_202210 = pd.read_csv('/Users/hyeokseung/Desktop/KHUDA_TOY/Data/숙박 여행 유형 정보/csv/CI_LDGMNT_TOUR_TY_INFO_202210.csv')
data_202211 = pd.read_csv('/Users/hyeokseung/Desktop/KHUDA_TOY/Data/숙박 여행 유형 정보/csv/CI_LDGMNT_TOUR_TY_INFO_202211.csv')
data_202212 = pd.read_csv('/Users/hyeokseung/Desktop/KHUDA_TOY/Data/숙박 여행 유형 정보/csv/CI_LDGMNT_TOUR_TY_INFO_202212.csv')

# %%
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
data_202210.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1916 entries, 0 to 1915
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RESPOND_ID             1916 non-null   int64
#  1   EXAMIN_YM              1916 non-null   int64
#  2   SEXDSTN_FLAG_CD        1916 non-null   object
#  3   AGRDE_FLAG_NM          1916 non-null   object
#  4   ANSWRR_OC_AREA_NM      1916 non-null   object
#  5   HSHLD_INCOME_DGREE_NM  1916 non-null   object
#  6   DMSTC_TOUR_TY_VALUE    1916 non-null   object
#  7   OVSEA_TOUR_TY_VALUE    1916 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 119.9+ KB

# %%
data_202211.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1537 entries, 0 to 1536
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RESPOND_ID             1537 non-null   int64
#  1   EXAMIN_YM              1537 non-null   int64
#  2   SEXDSTN_FLAG_CD        1537 non-null   object
#  3   AGRDE_FLAG_NM          1537 non-null   object
#  4   ANSWRR_OC_AREA_NM      1537 non-null   object
#  5   HSHLD_INCOME_DGREE_NM  1537 non-null   object
#  6   DMSTC_TOUR_TY_VALUE    1537 non-null   object
#  7   OVSEA_TOUR_TY_VALUE    1537 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 96.2+ KB

# %%
data_202212.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1515 entries, 0 to 1514
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RESPOND_ID             1515 non-null   int64
#  1   EXAMIN_YM              1515 non-null   int64
#  2   SEXDSTN_FLAG_CD        1515 non-null   object
#  3   AGRDE_FLAG_NM          1515 non-null   object
#  4   ANSWRR_OC_AREA_NM      1515 non-null   object
#  5   HSHLD_INCOME_DGREE_NM  1515 non-null   object
#  6   DMSTC_TOUR_TY_VALUE    1515 non-null   object
#  7   OVSEA_TOUR_TY_VALUE    1515 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 94.8+ KB

# %%
import matplotlib.pyplot as plt

# %%
data_202210['SEXDSTN_FLAG_CD'].value_counts().plot.pie(title='2022Y10M')
# Out:
# <AxesSubplot:title={'center':'2022Y10M'}, ylabel='SEXDSTN_FLAG_CD'>

# %%
data_202211['SEXDSTN_FLAG_CD'].value_counts().plot.pie(title='2022Y11M')
# Out:
# <AxesSubplot:title={'center':'2022Y11M'}, ylabel='SEXDSTN_FLAG_CD'>

# %%
data_202212['SEXDSTN_FLAG_CD'].value_counts().plot.pie(title='2022Y12M')
# Out:
# <AxesSubplot:title={'center':'2022Y12M'}, ylabel='SEXDSTN_FLAG_CD'>

# %%
data_202210['AGRDE_FLAG_NM'].value_counts().plot.pie(title='2022Y10M')
# Out:
# <AxesSubplot:title={'center':'2022Y10M'}, ylabel='AGRDE_FLAG_NM'>

# %%
data_202210['AGRDE_FLAG_NM'].value_counts()
# Out:
# 40대    447
# 50대    420
# 30대    371
# 60대    347
# 20대    331
# Name: AGRDE_FLAG_NM, dtype: int64

# %%
data_202211['AGRDE_FLAG_NM'].value_counts().plot.pie(title='2022Y11M')
# Out:
# <AxesSubplot:title={'center':'2022Y11M'}, ylabel='AGRDE_FLAG_NM'>

# %%
data_202212['AGRDE_FLAG_NM'].value_counts().plot.pie(title='2022Y12M')
# Out:
# <AxesSubplot:title={'center':'2022Y12M'}, ylabel='AGRDE_FLAG_NM'>

# %%
data_202210['ANSWRR_OC_AREA_NM'].value_counts().plot.bar(title='2022Y10M')
# Out:
# <AxesSubplot:title={'center':'2022Y10M'}>

# %%
data_202211['ANSWRR_OC_AREA_NM'].value_counts().plot.bar(title='2022Y11M')
# Out:
# <AxesSubplot:title={'center':'2022Y11M'}>

# %%
data_202212['ANSWRR_OC_AREA_NM'].value_counts().plot.bar(title='2022Y12M')
# Out:
# <AxesSubplot:title={'center':'2022Y12M'}>

# %%
data_202210['HSHLD_INCOME_DGREE_NM'].value_counts().plot.pie(title='2022Y10M')
# Out:
# <AxesSubplot:title={'center':'2022Y10M'}, ylabel='HSHLD_INCOME_DGREE_NM'>

# %%
data_202211['HSHLD_INCOME_DGREE_NM'].value_counts().plot.pie(title='2022Y11M')
# Out:
# <AxesSubplot:title={'center':'2022Y11M'}, ylabel='HSHLD_INCOME_DGREE_NM'>

# %%
data_202212['HSHLD_INCOME_DGREE_NM'].value_counts().plot.pie(title='2022Y12M')
# Out:
# <AxesSubplot:title={'center':'2022Y12M'}, ylabel='HSHLD_INCOME_DGREE_NM'>

# %%
data_202210['DMSTC_TOUR_TY_VALUE'].value_counts().plot.bar(title='2022Y10M')
# Out:
# <AxesSubplot:title={'center':'2022Y10M'}>

# %%
data_202212['DMSTC_TOUR_TY_VALUE'].value_counts().plot.bar(title='2022Y11M')
# Out:
# <AxesSubplot:title={'center':'2022Y11M'}>

# %%
data_202212['DMSTC_TOUR_TY_VALUE'].value_counts().plot.bar(title='2022Y12M')
# Out:
# <AxesSubplot:title={'center':'2022Y12M'}>

# %%
df = pd.read_csv('/Users/hyeokseung/Desktop/KHUDA_TOY/Data/숙박 여행 유형 정보/csv/LDGMENT_MERGE.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16553 entries, 0 to 16552
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             16553 non-null  int64
#  1   RESPOND_ID             16553 non-null  int64
#  2   EXAMIN_YM              16553 non-null  int64
#  3   SEXDSTN_FLAG_CD        16553 non-null  object
#  4   AGRDE_FLAG_NM          16553 non-null  object
#  5   ANSWRR_OC_AREA_NM      16553 non-null  object
#  6   HSHLD_INCOME_DGREE_NM  16553 non-null  object
#  7   DMSTC_TOUR_TY_VALUE    16553 non-null  object
#  8   OVSEA_TOUR_TY_VALUE    16553 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 1.1+ MB

# %%
df['AGRDE_FLAG_NM'].value_counts()
# Out:
# 40대    3775
# 50대    3705
# 30대    3138
# 60대    3099
# 20대    2836
# Name: AGRDE_FLAG_NM, dtype: int64

# %%
df['ANSWRR_OC_AREA_NM'].value_counts()
# Out:
# 경기도             4454
# 서울특별시           3264
# 부산광역시           1038
# 경상남도            1014
# 인천광역시            984
# 대구광역시            778
# 경상북도             766
# 충청남도(세종시 포함)     747
# 전라북도             538
# 전라남도             519
# 충청북도             512
# 강원도              482
# 대전광역시            472
# 광주광역시            450
# 울산광역시            362
# 제주도              173
# Name: ANSWRR_OC_AREA_NM, dtype: int64

# %%
df['HSHLD_INCOME_DGREE_NM'].value_counts()
# Out:
# 700만원 이상         4813
# 300이상500만원 미만    4485
# 500이상700만원 미만    4407
# 300만원 미만         1935
# 모름                913
# Name: HSHLD_INCOME_DGREE_NM, dtype: int64

# %%
df['DMSTC_TOUR_TY_VALUE'].value_counts()
# Out:
# 개별 여행                 14377
# 여행경험없음                 1299
# 에어텔 또는 에어카텔 패키지 여행      466
# 단체 패키지 여행               411
# Name: DMSTC_TOUR_TY_VALUE, dtype: int64
